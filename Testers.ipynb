# %% [markdown]
# Print 'Fizz' for multiples of 3 and 'Buzz' for multiples of 5 from 1 to 15.
#
# **Input:** None
#
# **Expected Output:** 1 2 Fizz 4 Buzz Fizz 7 8 Fizz Buzz 11 Fizz 13 14 FizzBuzz

# %%
x = 2+1
print(x)
# Out:
# 3
